# %% [markdown]
# **Math_Module_Built_in_Function**

# %%
import math as m

# %%
print(m.sqrt(8))
# Out:
# 2.8284271247461903

# %%
m.isqrt(17)
# Out:
# 4

# %%
print(m.ceil(+8.9))
# Out:
# 9

# %%
print(m.floor(25.98))
# Out:
# 25

# %%
print(m.trunc(4.9))
# Out:
# 4

# %%
m.log(17)
# Out:
# 2.833213344056216

# %%
m.gcd(24,36)
# Out:
# 12

# %%
m.fabs(-7.5)
# Out:
# 7.5

# %%
m.floor(4.9)
# Out:
# 4

# %%
m.sin(m.pi/2)
# Out:
# 1.0

# %%
m.pow(2, 10)
# Out:
# 1024.0

# %%
m.factorial(5)
# Out:
# 120

# %%
m.remainder(2, 10)

# %%
print(m.sin(10))
# Out:
# -0.5440211108893698

# %%
print(m.cos(10))
# Out:
# -0.8390715290764524

# %%
print(m.tan(10))
# Out:
# 0.6483608274590866

# %%
print(m.comb(5,2))
# Out:
# 10

# %%
print(m.sin(m.radians(30)))
# Out:
# 0.49999999999999994

# %% [markdown]
# **DataTime_Module_Function**

# %%
import datetime as dt

# %%
now=dt.datetime.now()
print(now)
# Out:
# 2026-04-02 14:18:39.444949

# %%
print(now.year)
# Out:
# 2026

# %%
print(now.day)
# Out:
# 2

# %%
print(now.date())
# Out:
# 2026-04-02

# %%
print(now.time())
# Out:
# 14:18:39.444949

# %%
d=dt.datetime(2006,7,18)
print(d)
# Out:
# 2006-07-18 00:00:00

# %%
# %Y: Full year with century (e.g., 2023)
# %m: Month as a zero-padded decimal number (e.g., 01, 12)
# %d: Day of the month as a zero-padded decimal number (e.g., 01, 31)
# %H: Hour (24-hour clock) as a zero-padded decimal number (e.g., 00, 23)
# %M: Minute as a zero-padded decimal number (e.g., 00, 59)
# %S: Second as a zero-padded decimal number (e.g., 00, 59)
# %A: Weekday as full name (e.g., Monday)
# %a: Weekday as abbreviated name (e.g., Mon)
# %B: Month as full name (e.g., January)
# %b: Month as abbreviated name (e.g., Jan)
# %c: Locale's appropriate date and time representation
# %x: Locale's appropriate date representation
# %X: Locale's appropriate time representation
format=now.strftime("%a%b,%y ")
print(format)
# Out:
# ThuApr,26

# %%
format=now.strftime("%A")
print(format)
# Out:
# Thursday
